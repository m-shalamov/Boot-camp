# %% [markdown]
# # Анализ данных

# %% [markdown]
# ## Lection

# %% [markdown]
# **Pandas**

# %%
import pandas as pd
df  =pd.DataFrame([
    ["Tom", 23, 177],
    ["Jack", 40, 190],
    ["Anna", 10, 130],
    ["Helen", 70, 170],
    ["Mike", 12, 150]
])
df
# Out:
#        0   1    2
# 0    Tom  23  177
# 1   Jack  40  190
# 2   Anna  10  130
# 3  Helen  70  170
# 4   Mike  12  150

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns = ["Name", "Age", "Height"]
df
# Out:
#     Name  Age  Height
# 0    Tom   23     177
# 1   Jack   40     190
# 2   Anna   10     130
# 3  Helen   70     170
# 4   Mike   12     150

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Height'], dtype='object')

# %%
df.iloc[1,2]
# Out:
# 190

# %%
df.iloc[0:2, 0:3]
# Out:
#    Name  Age  Height
# 0   Tom   23     177
# 1  Jack   40     190

# %%
df.iloc[[0,1], [0,2]]
# Out:
#    Name  Height
# 0   Tom     177
# 1  Jack     190

# %%
df.iloc[:, 2]
# Out:
# 0    177
# 1    190
# 2    130
# 3    170
# 4    150
# Name: Height, dtype: int64

# %%
df[["Name", "Age"]].loc[0:2]
# Out:
#    Name  Age
# 0   Tom   23
# 1  Jack   40
# 2  Anna   10

# %%
df[0:2]
# Out:
#    Name  Age  Height
# 0   Tom   23     177
# 1  Jack   40     190

# %%
df.index = df["Name"]

# %%
df
# Out:
#         Name  Age  Height
# Name
# Tom      Tom   23     177
# Jack    Jack   40     190
# Anna    Anna   10     130
# Helen  Helen   70     170
# Mike    Mike   12     150

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Tom to Mike
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Height  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 160.0+ bytes

# %%
df.shape
# Out:
# (5, 3)

# %%
df.describe()
# Out:
#              Age     Height
# count   5.000000    5.00000
# mean   31.000000  163.40000
# std    24.839485   23.61779
# min    10.000000  130.00000
# 25%    12.000000  150.00000
# 50%    23.000000  170.00000
# 75%    40.000000  177.00000
# max    70.000000  190.00000

# %%
df.head()
# Out:
#         Name  Age  Height
# Name
# Tom      Tom   23     177
# Jack    Jack   40     190
# Anna    Anna   10     130
# Helen  Helen   70     170
# Mike    Mike   12     150

# %%
df.tail(2)
# Out:
#         Name  Age  Height
# Name
# Helen  Helen   70     170
# Mike    Mike   12     150

# %%
df
# Out:
#         Name  Age  Height
# Name
# Tom      Tom   23     177
# Jack    Jack   40     190
# Anna    Anna   10     130
# Helen  Helen   70     170
# Mike    Mike   12     150

# %%
df[df["Age"]>18]
# Out:
#         Name  Age  Height
# Name
# Tom      Tom   23     177
# Jack    Jack   40     190
# Helen  Helen   70     170

# %%
df[(df["Age"]>18) & (df["Height"]>180)]
# Out:
#       Name  Age  Height
# Name
# Jack  Jack   40     190

# %%
df["Age"] += 1
df
# Out:
#         Name  Age  Height
# Name
# Tom      Tom   24     177
# Jack    Jack   41     190
# Anna    Anna   11     130
# Helen  Helen   71     170
# Mike    Mike   13     150

# %%
df["Sex"] = ["M", "M", "F", "F", "M"]

# %%
df
# Out:
#         Name  Age  Height Sex
# Name
# Tom      Tom   24     177   M
# Jack    Jack   41     190   M
# Anna    Anna   11     130   F
# Helen  Helen   71     170   F
# Mike    Mike   13     150   M

# %%
df
# Out:
#         Name  Age  Height Sex  \
# Name
# Tom      Tom   24     177   M
# Jack    Jack   41     190   M
# Anna    Anna   11     130   F
# Helen  Helen   71     170   F
# Mike    Mike   13     150   M
#
#                                              Height + cm
# Name
# Tom    Name\nTom      177\nJack     190\nAnna     130...
# Jack   Name\nTom      177\nJack     190\nAnna     130...
# Anna   Name\nTom      177\nJack     190\nAnna     130...
# Helen  Name\nTom      177\nJack     190\nAnna     130...
# Mike   Name\nTom      177\nJack     190\nAnna     130...

# %%
df["Age_pow"] = df["Age"]**2
df
# Out:
#         Name  Age  Height Sex  \
# Name
# Tom      Tom   24     177   M
# Jack    Jack   41     190   M
# Anna    Anna   11     130   F
# Helen  Helen   71     170   F
# Mike    Mike   13     150   M
#
#                                              Height + cm  Age_pow
# Name
# Tom    Name\nTom      177\nJack     190\nAnna     130...      576
# Jack   Name\nTom      177\nJack     190\nAnna     130...     1681
# Anna   Name\nTom      177\nJack     190\nAnna     130...      121
# Helen  Name\nTom      177\nJack     190\nAnna     130...     5041
# Mike   Name\nTom      177\nJack     190\nAnna     130...      169

# %%
df["t"] = 0
df
# Out:
#         Name  Age  Height Sex  \
# Name
# Tom      Tom   24     177   M
# Jack    Jack   41     190   M
# Anna    Anna   11     130   F
# Helen  Helen   71     170   F
# Mike    Mike   13     150   M
#
#                                              Height + cm  Age_pow  t
# Name
# Tom    Name\nTom      177\nJack     190\nAnna     130...      576  0
# Jack   Name\nTom      177\nJack     190\nAnna     130...     1681  0
# Anna   Name\nTom      177\nJack     190\nAnna     130...      121  0
# Helen  Name\nTom      177\nJack     190\nAnna     130...     5041  0
# Mike   Name\nTom      177\nJack     190\nAnna     130...      169  0

# %% [markdown]
# ## Practice

# %%
# Создать DataFrame на основе массива
import numpy as np

# arr= np.load("arr_pandas.npy", allow_pickle = True)
# df = pd.DataFrame(arr)
# df
# определить размерность массива
# df.shape
# для колонок задать названия: id, distance, height, time( в часах), time_female, type
# df.columns = [ "id", "distance", "height", "time_in_hour", "time_female", "type"]
# df
# Для первых 7 участников вывести id, distance, type
# df.head(7)[["id", "distance", "type"]]
# Вывести те строки, в которых type = hill. Найти кол-во строк
# len(df[df["type"]=="hill"])
# Добавить столбец со временем time в минутах 
# df["time_min"] = df["time_in_hour"] *60
# df
# Вывести строки со временем  time более 1 часа и высоты более 2000
# df[(df["time_in_hour"] > 1) & (df["height"] > 2000)]
# Out:
#                     id distance height time_in_hour time_female      type  \
# 3   The Devils Burdens     21.0   4100     2.399722    3.093333     relay
# 11   O.P.S. Clachnaben     10.5   3500     1.278889    1.487778      hill
# 14       Manx Mountain     30.5   8000     4.469722    5.523333  marathon
# 17       Stuc A'Chroin     14.0   5000     1.983333    2.398889      hill
# 19          Ben Lomond      9.0   3192     1.037778    1.199167      hill
# 21            Goatfell      8.0   2866     1.227778    1.526389      hill
# 24         Culter Fell     12.0   4000     1.721667    1.987778     other
# 25        Isle of Jura     16.0   7500     3.116389    3.839444     other
# 28        12 Trig Trog     46.0   7500     8.306944   13.547778      hill
# 32             Yetholm      8.0   2500     1.193056    1.451111      hill
# 34           Glen Rosa     13.0   5500     2.220278    2.704722      hill
# 35   West Highland Way     95.0   9200    15.438889   18.879167     other
# ...

# %% [markdown]
# ## Lection

# %%
df = pd.read_csv("WeightLoss.csv")
df
# Out:
#     id    group  w1  w2   w3   se1   se2   se3
# 0    1  Control   4   3  3.0  14.0  13.0  15.0
# 1    2  Control   4   4  3.0  13.0  14.0  17.0
# 2    3  Control   4   3  1.0  17.0  12.0  16.0
# 3    4  Control   3   2  1.0  11.0  11.0  12.0
# 4    5  Control   5   3  2.0  16.0  15.0  14.0
# 5    6  Control   6   5  4.0  17.0  18.0  18.0
# 6    7  Control   6   5  4.0  17.0  16.0  19.0
# 7    8  Control   5   4  1.0   NaN   NaN   NaN
# 8    9  Control   5   4  1.0  14.0  14.0  15.0
# 9   10  Control   3   3  2.0  14.0  15.0  13.0
# 10  11  Control   4   2  2.0  16.0  16.0  11.0
# 11  12  Control   5   2  1.0  15.0  13.0  16.0
# 12  13     Diet   6   3  2.0  12.0  11.0  14.0
# 13  14     Diet   5   4  1.0  13.0  14.0  15.0
# 14  15     Diet   7   6  3.0  17.0  11.0  18.0
# 15  16     Diet   6   4  2.0  16.0  15.0  18.0
# 16  17     Diet   3   2  1.0  16.0  17.0  15.0
# 17  18     Diet   5   5  4.0  13.0  11.0  18.0
# 18  19     Diet   4   3  1.0  12.0  11.0  14.0
# ...

# %%
df["sum"] = df["w1"]+df["w2"]+df["w3"]
df
# Out:
#     id    group  w1  w2   w3   se1   se2   se3   sum
# 0    1  Control   4   3  3.0  14.0  13.0  15.0  10.0
# 1    2  Control   4   4  3.0  13.0  14.0  17.0  11.0
# 2    3  Control   4   3  1.0  17.0  12.0  16.0   8.0
# 3    4  Control   3   2  1.0  11.0  11.0  12.0   6.0
# 4    5  Control   5   3  2.0  16.0  15.0  14.0  10.0
# 5    6  Control   6   5  4.0  17.0  18.0  18.0  15.0
# 6    7  Control   6   5  4.0  17.0  16.0  19.0  15.0
# 7    8  Control   5   4  1.0   NaN   NaN   NaN  10.0
# 8    9  Control   5   4  1.0  14.0  14.0  15.0  10.0
# 9   10  Control   3   3  2.0  14.0  15.0  13.0   8.0
# 10  11  Control   4   2  2.0  16.0  16.0  11.0   8.0
# 11  12  Control   5   2  1.0  15.0  13.0  16.0   8.0
# 12  13     Diet   6   3  2.0  12.0  11.0  14.0  11.0
# 13  14     Diet   5   4  1.0  13.0  14.0  15.0  10.0
# 14  15     Diet   7   6  3.0  17.0  11.0  18.0  16.0
# 15  16     Diet   6   4  2.0  16.0  15.0  18.0  12.0
# 16  17     Diet   3   2  1.0  16.0  17.0  15.0   6.0
# ...

# %%
df["sum"] = df["sum"].apply(np.sqrt)
df
# Out:
#     id    group  w1  w2   w3   se1   se2   se3       sum
# 0    1  Control   4   3  3.0  14.0  13.0  15.0  3.162278
# 1    2  Control   4   4  3.0  13.0  14.0  17.0  3.316625
# 2    3  Control   4   3  1.0  17.0  12.0  16.0  2.828427
# 3    4  Control   3   2  1.0  11.0  11.0  12.0  2.449490
# 4    5  Control   5   3  2.0  16.0  15.0  14.0  3.162278
# 5    6  Control   6   5  4.0  17.0  18.0  18.0  3.872983
# 6    7  Control   6   5  4.0  17.0  16.0  19.0  3.872983
# 7    8  Control   5   4  1.0   NaN   NaN   NaN  3.162278
# 8    9  Control   5   4  1.0  14.0  14.0  15.0  3.162278
# 9   10  Control   3   3  2.0  14.0  15.0  13.0  2.828427
# 10  11  Control   4   2  2.0  16.0  16.0  11.0  2.828427
# 11  12  Control   5   2  1.0  15.0  13.0  16.0  2.828427
# 12  13     Diet   6   3  2.0  12.0  11.0  14.0  3.316625
# 13  14     Diet   5   4  1.0  13.0  14.0  15.0  3.162278
# 14  15     Diet   7   6  3.0  17.0  11.0  18.0  4.000000
# ...

# %%
df["mean"]=df.loc[:, "w1":"w3"].apply(np.mean, axis=1)
df
# Out:
#     id    group  w1  w2   w3   se1   se2   se3   sum      mean
# 0    1  Control   4   3  3.0  14.0  13.0  15.0  10.0  3.333333
# 1    2  Control   4   4  3.0  13.0  14.0  17.0  11.0  3.666667
# 2    3  Control   4   3  1.0  17.0  12.0  16.0   8.0  2.666667
# 3    4  Control   3   2  1.0  11.0  11.0  12.0   6.0  2.000000
# 4    5  Control   5   3  2.0  16.0  15.0  14.0  10.0  3.333333
# 5    6  Control   6   5  4.0  17.0  18.0  18.0  15.0  5.000000
# 6    7  Control   6   5  4.0  17.0  16.0  19.0  15.0  5.000000
# 7    8  Control   5   4  1.0   NaN   NaN   NaN  10.0  3.333333
# 8    9  Control   5   4  1.0  14.0  14.0  15.0  10.0  3.333333
# 9   10  Control   3   3  2.0  14.0  15.0  13.0   8.0  2.666667
# 10  11  Control   4   2  2.0  16.0  16.0  11.0   8.0  2.666667
# 11  12  Control   5   2  1.0  15.0  13.0  16.0   8.0  2.666667
# 12  13     Diet   6   3  2.0  12.0  11.0  14.0  11.0  3.666667
# 13  14     Diet   5   4  1.0  13.0  14.0  15.0  10.0  3.333333
# ...

# %%
df["delta"]=df.loc[:,"w1":"w3"].apply(lambda w: w.max() - w.min(), axis = 1)
df
# Out:
#     id    group  w1  w2   w3   se1   se2   se3   sum      mean  delta
# 0    1  Control   4   3  3.0  14.0  13.0  15.0  10.0  3.333333    1.0
# 1    2  Control   4   4  3.0  13.0  14.0  17.0  11.0  3.666667    1.0
# 2    3  Control   4   3  1.0  17.0  12.0  16.0   8.0  2.666667    3.0
# 3    4  Control   3   2  1.0  11.0  11.0  12.0   6.0  2.000000    2.0
# 4    5  Control   5   3  2.0  16.0  15.0  14.0  10.0  3.333333    3.0
# 5    6  Control   6   5  4.0  17.0  18.0  18.0  15.0  5.000000    2.0
# 6    7  Control   6   5  4.0  17.0  16.0  19.0  15.0  5.000000    2.0
# 7    8  Control   5   4  1.0   NaN   NaN   NaN  10.0  3.333333    4.0
# 8    9  Control   5   4  1.0  14.0  14.0  15.0  10.0  3.333333    4.0
# 9   10  Control   3   3  2.0  14.0  15.0  13.0   8.0  2.666667    1.0
# 10  11  Control   4   2  2.0  16.0  16.0  11.0   8.0  2.666667    2.0
# 11  12  Control   5   2  1.0  15.0  13.0  16.0   8.0  2.666667    4.0
# ...

# %%
group = df.groupby("group")
group
list(group)[2]
# Out:
# ('DietEx',
#      id   group  w1  w2   w3   se1   se2   se3   sum      mean  delta
#  24  25  DietEx   7   7  4.0  15.0  11.0  19.0  18.0  6.000000    3.0
#  25  26  DietEx   4   7  NaN  16.0  12.0  18.0   NaN  5.500000    3.0
#  26  27  DietEx   9   7  3.0  13.0  12.0  17.0  19.0  6.333333    6.0
#  27  28  DietEx   3   4  1.0  16.0  13.0   NaN   8.0  2.666667    3.0
#  28  29  DietEx   3   5  1.0  13.0  13.0  16.0   9.0  3.000000    4.0
#  29  30  DietEx   6   5  2.0  15.0  12.0  18.0  13.0  4.333333    4.0
#  30  31  DietEx   6   6  3.0  15.0  13.0  18.0  15.0  5.000000    3.0
#  31  32  DietEx   9   5  2.0  16.0  14.0  17.0  16.0  5.333333    7.0
#  32  33  DietEx   7   9  4.0  16.0  16.0  19.0  20.0  6.666667    5.0
#  33  34  DietEx   8   6  1.0  17.0  17.0  17.0  15.0  5.000000    7.0)

# %%
group.agg("sum")["w2"]
# Out:
# group
# Control    40
# Diet       47
# DietEx     61
# Name: w2, dtype: int64

# %%
group.agg(["min", "max"])
# Out:
#          id      w1      w2       w3        se1         se2         se3        \
#         min max min max min max  min  max   min   max   min   max   min   max
# group
# Control   1  12   3   6   2   5  1.0  4.0  11.0  17.0  11.0  18.0  11.0  19.0
# Diet     13  24   3   7   2   6  1.0  4.0  12.0  19.0  11.0  19.0  11.0  19.0
# DietEx   25  34   3   9   4   9  1.0  4.0  13.0  17.0  11.0  17.0  16.0  19.0
#
#          sum            mean           delta
#          min   max       min       max   min  max
# group
# Control  6.0  15.0  2.000000  5.000000   1.0  4.0
# Diet     6.0  17.0  2.000000  5.666667   1.0  4.0
# DietEx   8.0  20.0  2.666667  6.666667   3.0  7.0

# %%
df
# Out:
#     id    group  w1  w2   w3   se1   se2   se3   sum      mean  delta
# 0    1  Control   4   3  3.0  14.0  13.0  15.0  10.0  3.333333    1.0
# 1    2  Control   4   4  3.0  13.0  14.0  17.0  11.0  3.666667    1.0
# 2    3  Control   4   3  1.0  17.0  12.0  16.0   8.0  2.666667    3.0
# 3    4  Control   3   2  1.0  11.0  11.0  12.0   6.0  2.000000    2.0
# 4    5  Control   5   3  2.0  16.0  15.0  14.0  10.0  3.333333    3.0
# 5    6  Control   6   5  4.0  17.0  18.0  18.0  15.0  5.000000    2.0
# 6    7  Control   6   5  4.0  17.0  16.0  19.0  15.0  5.000000    2.0
# 7    8  Control   5   4  1.0   NaN   NaN   NaN  10.0  3.333333    4.0
# 8    9  Control   5   4  1.0  14.0  14.0  15.0  10.0  3.333333    4.0
# 9   10  Control   3   3  2.0  14.0  15.0  13.0   8.0  2.666667    1.0
# 10  11  Control   4   2  2.0  16.0  16.0  11.0   8.0  2.666667    2.0
# 11  12  Control   5   2  1.0  15.0  13.0  16.0   8.0  2.666667    4.0
# ...

# %%
df.sort_values("sum", ascending=False, inplace=True)
# Out:
#     id    group  w1  w2   w3   se1   se2   se3   sum      mean  delta
# 32  33   DietEx   7   9  4.0  16.0  16.0  19.0  20.0  6.666667    5.0
# 26  27   DietEx   9   7  3.0  13.0  12.0  17.0  19.0  6.333333    6.0
# 24  25   DietEx   7   7  4.0  15.0  11.0  19.0  18.0  6.000000    3.0
# 21  22     Diet   7   6  4.0  19.0  19.0  19.0  17.0  5.666667    3.0
# 31  32   DietEx   9   5  2.0  16.0  14.0  17.0  16.0  5.333333    7.0
# 14  15     Diet   7   6  3.0  17.0  11.0  18.0  16.0  5.333333    4.0
# 33  34   DietEx   8   6  1.0  17.0  17.0  17.0  15.0  5.000000    7.0
# 6    7  Control   6   5  4.0  17.0  16.0  19.0  15.0  5.000000    2.0
# 5    6  Control   6   5  4.0  17.0  18.0  18.0  15.0  5.000000    2.0
# 30  31   DietEx   6   6  3.0  15.0  13.0  18.0  15.0  5.000000    3.0
# 17  18     Diet   5   5  4.0  13.0  11.0  18.0  14.0  4.666667    1.0
# 23  24     Diet   7   4  3.0  16.0  14.0  18.0  14.0  4.666667    4.0
# ...

# %%
df.sort_values(["w1", "w2"], ascending=False)
# Out:
#     id    group  w1  w2   w3   se1   se2   se3   sum      mean  delta
# 26  27   DietEx   9   7  3.0  13.0  12.0  17.0  19.0  6.333333    6.0
# 31  32   DietEx   9   5  2.0  16.0  14.0  17.0  16.0  5.333333    7.0
# 33  34   DietEx   8   6  1.0  17.0  17.0  17.0  15.0  5.000000    7.0
# 32  33   DietEx   7   9  4.0  16.0  16.0  19.0  20.0  6.666667    5.0
# 24  25   DietEx   7   7  4.0  15.0  11.0  19.0  18.0  6.000000    3.0
# 14  15     Diet   7   6  3.0  17.0  11.0  18.0  16.0  5.333333    4.0
# 21  22     Diet   7   6  4.0  19.0  19.0  19.0  17.0  5.666667    3.0
# 23  24     Diet   7   4  3.0  16.0  14.0  18.0  14.0  4.666667    4.0
# 30  31   DietEx   6   6  3.0  15.0  13.0  18.0  15.0  5.000000    3.0
# 5    6  Control   6   5  4.0  17.0  18.0  18.0  15.0  5.000000    2.0
# 6    7  Control   6   5  4.0  17.0  16.0  19.0  15.0  5.000000    2.0
# 20  21     Diet   6   5  3.0  17.0  16.0  19.0  14.0  4.666667    3.0
# ...

# %%
df.isnull()
# Out:
#        id  group     w1     w2     w3    se1    se2    se3    sum   mean  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False   True   True   True  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.fillna(0)
# Out:
#     id    group  w1  w2   w3   se1   se2   se3   sum      mean  delta
# 0    1  Control   4   3  3.0  14.0  13.0  15.0  10.0  3.333333    1.0
# 1    2  Control   4   4  3.0  13.0  14.0  17.0  11.0  3.666667    1.0
# 2    3  Control   4   3  1.0  17.0  12.0  16.0   8.0  2.666667    3.0
# 3    4  Control   3   2  1.0  11.0  11.0  12.0   6.0  2.000000    2.0
# 4    5  Control   5   3  2.0  16.0  15.0  14.0  10.0  3.333333    3.0
# 5    6  Control   6   5  4.0  17.0  18.0  18.0  15.0  5.000000    2.0
# 6    7  Control   6   5  4.0  17.0  16.0  19.0  15.0  5.000000    2.0
# 7    8  Control   5   4  1.0   0.0   0.0   0.0  10.0  3.333333    4.0
# 8    9  Control   5   4  1.0  14.0  14.0  15.0  10.0  3.333333    4.0
# 9   10  Control   3   3  2.0  14.0  15.0  13.0   8.0  2.666667    1.0
# 10  11  Control   4   2  2.0  16.0  16.0  11.0   8.0  2.666667    2.0
# 11  12  Control   5   2  1.0  15.0  13.0  16.0   8.0  2.666667    4.0
# ...

# %%
df
# Out:
#     id    group  w1  w2   w3   se1   se2   se3   sum      mean  delta
# 0    1  Control   4   3  3.0  14.0  13.0  15.0  10.0  3.333333    1.0
# 1    2  Control   4   4  3.0  13.0  14.0  17.0  11.0  3.666667    1.0
# 2    3  Control   4   3  1.0  17.0  12.0  16.0   8.0  2.666667    3.0
# 3    4  Control   3   2  1.0  11.0  11.0  12.0   6.0  2.000000    2.0
# 4    5  Control   5   3  2.0  16.0  15.0  14.0  10.0  3.333333    3.0
# 5    6  Control   6   5  4.0  17.0  18.0  18.0  15.0  5.000000    2.0
# 6    7  Control   6   5  4.0  17.0  16.0  19.0  15.0  5.000000    2.0
# 7    8  Control   5   4  1.0   NaN   NaN   NaN  10.0  3.333333    4.0
# 8    9  Control   5   4  1.0  14.0  14.0  15.0  10.0  3.333333    4.0
# 9   10  Control   3   3  2.0  14.0  15.0  13.0   8.0  2.666667    1.0
# 10  11  Control   4   2  2.0  16.0  16.0  11.0   8.0  2.666667    2.0
# 11  12  Control   5   2  1.0  15.0  13.0  16.0   8.0  2.666667    4.0
# ...

# %%
df.dropna()

# %%
df.sort_index()
# Out:
#     id    group  w1  w2   w3   se1   se2   se3   sum      mean  delta
# 0    1  Control   4   3  3.0  14.0  13.0  15.0  10.0  3.333333    1.0
# 1    2  Control   4   4  3.0  13.0  14.0  17.0  11.0  3.666667    1.0
# 2    3  Control   4   3  1.0  17.0  12.0  16.0   8.0  2.666667    3.0
# 3    4  Control   3   2  1.0  11.0  11.0  12.0   6.0  2.000000    2.0
# 4    5  Control   5   3  2.0  16.0  15.0  14.0  10.0  3.333333    3.0
# 5    6  Control   6   5  4.0  17.0  18.0  18.0  15.0  5.000000    2.0
# 6    7  Control   6   5  4.0  17.0  16.0  19.0  15.0  5.000000    2.0
# 7    8  Control   5   4  1.0   NaN   NaN   NaN  10.0  3.333333    4.0
# 8    9  Control   5   4  1.0  14.0  14.0  15.0  10.0  3.333333    4.0
# 9   10  Control   3   3  2.0  14.0  15.0  13.0   8.0  2.666667    1.0
# 10  11  Control   4   2  2.0  16.0  16.0  11.0   8.0  2.666667    2.0
# 11  12  Control   5   2  1.0  15.0  13.0  16.0   8.0  2.666667    4.0
# ...

# %% [markdown]
# ## Visualization

# %%
import pandas as pd
df = pd.read_csv("winemag-data_first150k.csv")
df
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df["province"].value_counts().head(8).plot(kind="bar")
df["province"].value_counts().head(8).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df["province"].value_counts().head(8).plot.barh()
# Out:
# <AxesSubplot:>

# %%
df["province"].value_counts()
# Out:
# California          44508
# Washington           9750
# Tuscany              7281
# Bordeaux             6111
# Northern Spain       4892
#                     ...
# Cape South Coast        1
# Sterea Ellada           1
# Pannon                  1
# Neuchâtel               1
# Dalmatian Coast         1
# Name: province, Length: 455, dtype: int64

# %%
df["points"].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# df["points"].value_counts().sort_index().plot.line()

df[df["province"] == "Oregon"]["points"].value_counts().sort_index().plot.line()
df[df["province"] == "Northern Spain"]["points"].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df["points"].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
df[df["price"]<100].plot.scatter(x = "price", y = "points")
# Out:
# <AxesSubplot:xlabel='price', ylabel='points'>

# %%
df[df["price"]<100].plot.hexbin(x = "price", y = "points", gridsize = 15)
# Out:
# <AxesSubplot:xlabel='price', ylabel='points'>
