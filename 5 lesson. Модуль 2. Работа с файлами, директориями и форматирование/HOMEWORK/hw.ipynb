# %% [markdown]
# # Задание 1

# %%
Пользователь вводит абсолютный путь к директории с большим количеством фотографий, лежащих в этой директории. Далее пользователь вводит параметр, по которому нужно группировать фотографии(год, год+месяц, год+месяц+день). Разделить фотографии, по папкам по заданному параметру группировки. Папки создаются динамически исходя из даты создания(редактирования) изображения(файла). Примеры см ниже.

# %% [markdown]
# __год__

# %%
--2018
----фотографии
--2017
----фотографии
--2016
----фотографии

# %% [markdown]
# __год__ __месяц__

# %%
--2018
----июнь
------фотографии
----март
------фотографии
----январь
------фотографии
--2017
----сентябрь
------фотографии
----март
------фотографии
----февраль
------фотографии
--2016
----август
------фотографии
----март
------фотографии

# %% [markdown]
# __год__ __месяц__ __день__

# %%
--2018
----июнь
------4
--------фотографии
------1
--------фотографии
----март
------11
--------фотографии
------10
--------фотографии
----январь
------9
--------фотографии
------4
--------фотографии
--2017
----сентябрь
------18
--------фотографии
------4
--------фотографии
----март
------11
--------фотографии
------4
--------фотографии
----февраль
------11
--------фотографии
------4
--------фотографии
--2016
----август
------11
--------фотографии
------4
--------фотографии
------2
--------фотографии
----март
------11
--------фотографии
------4
--------фотографии

# %% [markdown]
# # Задание 2

# %%
Модифицировать блокировщик сайтов таким образом, чтобы он убирал блокировку в нерабочее время.(sites_blocking.py)
